# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import GridSearchCV


sns.set(style="white")

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./df_foodaccess_allmortality_SVI.csv')

# %% [markdown]
# ## <font color = darkorchid> Feature Selection </font>

# %%
# Create feature list with percentage metrics
features_proportional_share = ['lablack10share', 'lablack20share', 
                               'lahisp10share', 'lahisp20share', 
                               'lahunv10share', 'lahunv20share', 
                               'lasnap10share', 'lasnap20share',
                               'lawhite10share', 'lawhite20share',
                               'lalowi10share', 'lalowi20share', 
                               'lapop10share', 'lapop20share',
                               #'GroupQuartersFlag', 
                               #'PovertyRate',
                               #'LILATracts_1And10', 'LILATracts_1And20',
                               #'LILATracts_Vehicle', 'LILATracts_halfAnd10', 
                               #'LowIncomeTracts',
                               #'LA1and10', 'LA1and20', 'LAhalfand10',
                              ]

# %%
# Log transformation
for feature in features_proportional_share:
    df[f'{feature} Log10'] = np.log10(df[feature])
    
# Create new Log10 feature list
features_proportional_share_Log10 = [f'{x} Log10' for x in features_proportional_share]

# Convert -inf to 0for log_feature in features_proportional_share_Log10:
for log_feature in features_proportional_share_Log10:
    df.loc[df[log_feature] == -np.inf, log_feature] = np.log(0.0001)

# %%
# Set age adjusted rates as targets
target_list = ['Age Adjusted Rate Endocrine',
               'Age Adjusted Rate Obesity', 'Age Adjusted Rate Metabolic', 'Age Adjusted Rate Diabetes', 
               'Age Adjusted Rate Circulatory',
               'Age Adjusted Rate Pulmonary', 'Age Adjusted Rate Arteries', 'Age Adjusted Rate Hypertension',
               'Age Adjusted Rate External',
               'Age Adjusted Rate Assault', 'Age Adjusted Rate Intentional', 'Age Adjusted Rate Transport',
               'Age Adjusted Rate Mental',
               'Age Adjusted Rate Psychoactive',
               'Age Adjusted Rate Neoplasms', 
               'Age Adjusted Rate MalignantDigestive', 'Age Adjusted Rate MalignantBreast', 'Age Adjusted Rate MalignantFemale', 'Age Adjusted Rate MalignantMale', 'Age Adjusted Rate MalignantEndocrine',
               'Age Adjusted Rate All']

# %%
# Define function to consolidate r2 & MAE
def make_scores_df(r2_train, r2_test, mae_train, mae_test, model):
    r2 = pd.DataFrame(data = np.array([[np.mean(r2_train)],[np.mean(r2_test)]]), 
                 index = ['R^2 Train', 'R^2 Test'], columns = [model])

    mae = pd.DataFrame(data = np.array([[np.mean(mae_train)],[np.mean(mae_test)]]), 
                 index = ['MAE Train', 'MAE Test'], columns = [model])

    combined_scores = pd.merge(r2, mae, on = model, how = 'outer',
                               left_index = True, right_index = True)
    
    return combined_scores

# %% [markdown]
# ## <font color = darkorchid> Linear Regression </font>

# %%
scores_lin_reg = pd.DataFrame()

for t in target_list:
    # Drop if target value is not available
    df_linear = df.dropna(subset = [t])
    
    # Bootstrap observations
    df_linear_sample = df_linear.sample(n = df_linear.shape[0], replace = True)

    df_linear = pd.concat([df_linear, df_linear_sample])

    # Set features to percentage metrics
    X = df_linear[features_proportional_share_Log10]
    y = df_linear[t]
    
    # Train / Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    # StandardScale features
    #ss = StandardScaler()
    #X_train = ss.fit_transform(X_train)
    #X_test = ss.transform(X_test)
    
    ### Linear Regression
    
    # Fit OLS Linear Regression
    lin_reg = linear_model.LinearRegression(n_jobs = -1)
    lin_reg.fit(X_train, y_train)
    
    # Evaluate baseline train scores (r2)
    lin_reg_cv_score = cross_val_score(lin_reg, X_train, y_train , cv=3, scoring= 'r2', n_jobs = -1)
    
    # Evaluate baseline test scores (r2)
    lin_reg_cv_score_test = cross_val_score(lin_reg, X_test, y_test , cv=3, scoring= 'r2', n_jobs = -1)
    
    # Evaluate baseline train scores (MAE)
    lin_reg_cv_score_mae = cross_val_score(lin_reg, X_train, y_train , 
                                           cv=3, scoring= 'neg_mean_absolute_error', n_jobs = -1)
    
    
    # Evaluate baseline test scores (MAE)
    lin_reg_cv_score_mae_test = cross_val_score(lin_reg, X_test, y_test , 
                                                cv=3, scoring= 'neg_mean_absolute_error', n_jobs = -1)
    
    # Create dataframe of scores
    
    if scores_lin_reg.shape[0] == 0:
        scores_lin_reg = make_scores_df(lin_reg_cv_score, lin_reg_cv_score_test, 
                                        lin_reg_cv_score_mae, lin_reg_cv_score_mae_test,
                                        f'Log Linear Regression - {t}')
    else:
        scores_lin_reg_temp = make_scores_df(lin_reg_cv_score, lin_reg_cv_score_test, 
                                             lin_reg_cv_score_mae, lin_reg_cv_score_mae_test,
                                             f'Log Linear Regression - {t}')
        
        scores_lin_reg = pd.concat([scores_lin_reg, scores_lin_reg_temp], axis = 1)

scores_lin_reg.T
# Out:
#                                                         MAE Test   MAE Train  \
# Log Linear Regression - Age Adjusted Rate Endoc... -1.197030e+01  -11.225318
# Log Linear Regression - Age Adjusted Rate Obesity  -1.967871e+10   -0.861631
# Log Linear Regression - Age Adjusted Rate Metab... -2.453518e+00   -2.548962
# Log Linear Regression - Age Adjusted Rate Diabetes -9.222473e+00   -8.815820
# Log Linear Regression - Age Adjusted Rate Circu... -4.563179e+01  -45.629989
# Log Linear Regression - Age Adjusted Rate Pulmo... -3.350013e+00   -2.237147
# Log Linear Regression - Age Adjusted Rate Arteries -5.973244e+00   -5.475674
# Log Linear Regression - Age Adjusted Rate Hyper... -1.027322e+01   -9.740101
# Log Linear Regression - Age Adjusted Rate External -2.090251e+01  -20.215868
# Log Linear Regression - Age Adjusted Rate Assault  -4.193660e+00   -4.296603
# Log Linear Regression - Age Adjusted Rate Inten... -4.516795e+00   -4.384833
# Log Linear Regression - Age Adjusted Rate Trans... -6.886124e+00   -8.015524
# Log Linear Regression - Age Adjusted Rate Mental   -1.225108e+01  -12.399513
# Log Linear Regression - Age Adjusted Rate Psych... -2.065729e+00   -1.617003
# Log Linear Regression - Age Adjusted Rate Neopl... -2.566797e+01  -26.142307
# Log Linear Regression - Age Adjusted Rate Malig... -8.901008e+00   -8.712827
# Log Linear Regression - Age Adjusted Rate Malig... -2.729884e+00   -2.799346
# Log Linear Regression - Age Adjusted Rate Malig... -2.100215e+00   -1.954341
# Log Linear Regression - Age Adjusted Rate Malig... -2.650665e+00   -2.781400
# Log Linear Regression - Age Adjusted Rate Malig... -2.370104e+09   -0.234742
# Log Linear Regression - Age Adjusted Rate All      -1.043729e+02 -103.968395
#
#                                                         R^2 Test  R^2 Train
# Log Linear Regression - Age Adjusted Rate Endoc...  2.006464e-01   0.143241
# Log Linear Regression - Age Adjusted Rate Obesity  -2.525960e+22  -0.131764
# Log Linear Regression - Age Adjusted Rate Metab...  6.107496e-02   0.065478
# Log Linear Regression - Age Adjusted Rate Diabetes  9.193800e-02   0.213337
# Log Linear Regression - Age Adjusted Rate Circu...  1.139644e-01   0.169662
# Log Linear Regression - Age Adjusted Rate Pulmo... -8.621794e-02   0.031992
# Log Linear Regression - Age Adjusted Rate Arteries -1.906051e-01   0.040363
# Log Linear Regression - Age Adjusted Rate Hyper...  5.816369e-02   0.176077
# Log Linear Regression - Age Adjusted Rate External  1.608626e-01   0.151708
# Log Linear Regression - Age Adjusted Rate Assault  -2.057082e+00  -0.149568
# Log Linear Regression - Age Adjusted Rate Inten...  1.071892e-01   0.096847
# Log Linear Regression - Age Adjusted Rate Trans...  2.011525e-01   0.232434
# Log Linear Regression - Age Adjusted Rate Mental   -1.753197e-02   0.016981
# Log Linear Regression - Age Adjusted Rate Psych... -7.323448e-01   0.364308
# Log Linear Regression - Age Adjusted Rate Neopl...  4.279978e-02   0.086206
# Log Linear Regression - Age Adjusted Rate Malig...  2.741774e-02   0.057484
# Log Linear Regression - Age Adjusted Rate Malig... -1.364055e-01   0.031805
# Log Linear Regression - Age Adjusted Rate Malig... -9.911535e-02  -0.002412
# Log Linear Regression - Age Adjusted Rate Malig...  3.442402e-02   0.045760
# Log Linear Regression - Age Adjusted Rate Malig... -2.912057e+21  -2.121898
# Log Linear Regression - Age Adjusted Rate All       2.065776e-01   0.197063

# %% [markdown]
# ## <font color = darkorchid> Ridge Regression </font>

# %%
scores_ridge = pd.DataFrame()

for t in target_list:
    # Drop if target value is not available
    df_ridge = df.dropna(subset = [t])
    
    # Bootstrap observations
    df_ridge_sample = df_ridge.sample(n = df_ridge.shape[0], replace = True)

    df_ridge = pd.concat([df_ridge, df_ridge_sample])

    # Set features to percentage metrics
    X = df_ridge[features_proportional_share_Log10]
    y = df_ridge[t]
    
    # Train / Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    # StandardScale features
    ss = StandardScaler()
    X_train = ss.fit_transform(X_train)
    X_test = ss.transform(X_test)
    
    ### Ridge Regression CV
    
    # Define log space for possible alphas
    ridge_alphas = np.logspace(0, 5, 250)

    # Instantiate and fit ridge regression
    ridge = linear_model.RidgeCV(alphas=ridge_alphas, cv=3)
    ridge.fit(X_train, y_train)
    
    # Evaluate baseline train scores (MAE)
    ridge_cv_score_mae = cross_val_score(ridge, X_train, y_train , cv=3, 
                                         scoring= 'neg_mean_absolute_error', n_jobs = -1, verbose = 1)
    
    # Evaluate baseline test scores (MAE)
    ridge_cv_score_mae_test = cross_val_score(ridge, X_test, y_test , cv=3, 
                                              scoring= 'neg_mean_absolute_error', n_jobs = -1, verbose = 1)
    
    # Create dataframe of scores
    
    if scores_ridge.shape[0] == 0:
        scores_ridge = make_scores_df(ridge.score(X_train, y_train), ridge.score(X_test, y_test), 
                                      np.mean(ridge_cv_score_mae), np.mean(ridge_cv_score_mae_test),
                                      f'Log Ridge - {t}')
    else:
        scores_ridge_temp = make_scores_df(ridge.score(X_train, y_train), ridge.score(X_test, y_test), 
                                           np.mean(ridge_cv_score_mae), np.mean(ridge_cv_score_mae_test),
                                           f'Log Ridge - {t}')
        
        scores_ridge = pd.concat([scores_ridge, scores_ridge_temp], axis = 1)

scores_ridge.T
# Out:
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.4min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   10.2s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.8min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   10.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    8.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    9.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    8.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   12.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    8.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    8.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    8.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.6min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    8.8s finished
#                                                     MAE Test   MAE Train  \
# Log Ridge - Age Adjusted Rate Endocrine           -11.323795  -11.335230
# Log Ridge - Age Adjusted Rate Obesity              -0.744592   -0.787173
# Log Ridge - Age Adjusted Rate Metabolic            -2.796444   -2.560464
# Log Ridge - Age Adjusted Rate Diabetes             -8.695870   -9.006685
# Log Ridge - Age Adjusted Rate Circulatory         -47.654106  -44.612916
# Log Ridge - Age Adjusted Rate Pulmonary            -2.591769   -2.295320
# Log Ridge - Age Adjusted Rate Arteries             -5.546729   -4.903017
# Log Ridge - Age Adjusted Rate Hypertension        -11.121742  -10.022309
# Log Ridge - Age Adjusted Rate External            -20.272203  -19.735345
# Log Ridge - Age Adjusted Rate Assault              -3.271761   -3.855001
# Log Ridge - Age Adjusted Rate Intentional          -4.723130   -4.464662
# Log Ridge - Age Adjusted Rate Transport            -7.647181   -8.113584
# Log Ridge - Age Adjusted Rate Mental              -12.120824  -12.005096
# Log Ridge - Age Adjusted Rate Psychoactive         -1.786657   -1.700838
# Log Ridge - Age Adjusted Rate Neoplasms           -25.422230  -25.724341
# Log Ridge - Age Adjusted Rate MalignantDigestive   -8.570827   -8.526284
# Log Ridge - Age Adjusted Rate MalignantBreast      -2.747644   -2.777858
# Log Ridge - Age Adjusted Rate MalignantFemale      -1.810638   -1.980033
# Log Ridge - Age Adjusted Rate MalignantMale        -2.749982   -2.362320
# Log Ridge - Age Adjusted Rate MalignantEndocrine   -0.111630   -0.133114
# Log Ridge - Age Adjusted Rate All                -104.588217 -102.773958
#
#                                                   R^2 Test  R^2 Train
# Log Ridge - Age Adjusted Rate Endocrine           0.210922   0.196516
# Log Ridge - Age Adjusted Rate Obesity             0.212890   0.187625
# Log Ridge - Age Adjusted Rate Metabolic           0.129126   0.116712
# Log Ridge - Age Adjusted Rate Diabetes            0.300766   0.271409
# Log Ridge - Age Adjusted Rate Circulatory         0.158279   0.200038
# Log Ridge - Age Adjusted Rate Pulmonary           0.085266   0.096800
# Log Ridge - Age Adjusted Rate Arteries            0.030057   0.095420
# Log Ridge - Age Adjusted Rate Hypertension        0.201636   0.191771
# Log Ridge - Age Adjusted Rate External            0.125756   0.169313
# Log Ridge - Age Adjusted Rate Assault             0.178400   0.120626
# Log Ridge - Age Adjusted Rate Intentional         0.281941   0.220835
# Log Ridge - Age Adjusted Rate Transport           0.237630   0.246939
# Log Ridge - Age Adjusted Rate Mental              0.023900   0.041174
# Log Ridge - Age Adjusted Rate Psychoactive        0.334710   0.367152
# Log Ridge - Age Adjusted Rate Neoplasms           0.111932   0.095295
# Log Ridge - Age Adjusted Rate MalignantDigestive  0.090100   0.076248
# Log Ridge - Age Adjusted Rate MalignantBreast     0.085773   0.072852
# Log Ridge - Age Adjusted Rate MalignantFemale     0.024176   0.061188
# Log Ridge - Age Adjusted Rate MalignantMale       0.150041   0.151778
# Log Ridge - Age Adjusted Rate MalignantEndocrine  0.075364   0.543753
# Log Ridge - Age Adjusted Rate All                 0.175490   0.240184

# %% [markdown]
# ## <font color = darkorchid> Lasso Regression </font>

# %%
scores_lasso = pd.DataFrame()

for t in target_list:
    # Drop if target value is not available
    df_lasso = df.dropna(subset = [t])
    
    # Bootstrap observations
    df_lasso_sample = df_lasso.sample(n = df_lasso.shape[0], replace = True)

    df_lasso = pd.concat([df_lasso, df_lasso_sample])

    # Set features to percentage metrics
    X = df_lasso[features_proportional_share_Log10]
    y = df_lasso[t]
    
    # Train / Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    # StandardScale features
    #ss = StandardScaler()
    #X_train = ss.fit_transform(X_train)
    #X_test = ss.transform(X_test)
    
    ### Lasso Regression CV

    # Instantiate and fit lasso regression
    lasso = linear_model.LassoCV(eps = .001, n_alphas = 500, max_iter = 5000)
    lasso.fit(X_train, y_train)
    
    # Evaluate baseline train scores (MAE)
    lasso_cv_score_mae = cross_val_score(lasso, X_train, y_train , cv=3, verbose = 1,
                                         scoring= 'neg_mean_absolute_error', n_jobs = -1)
    
    # Evaluate baseline test scores (MAE)
    lasso_cv_score_mae_test = cross_val_score(lasso, X_test, y_test , cv=3, verbose = 1,
                                              scoring= 'neg_mean_absolute_error', n_jobs = -1)
    
    # Create dataframe of scores
    
    if scores_lasso.shape[0] == 0:
        scores_lasso = make_scores_df(lasso.score(X_train, y_train), lasso.score(X_test, y_test), 
                                      np.mean(lasso_cv_score_mae), np.mean(lasso_cv_score_mae_test),
                                      f'Log Lasso - {t}' )
    else:
        scores_lasso_temp = make_scores_df(lasso.score(X_train, y_train), lasso.score(X_test, y_test), 
                                           np.mean(lasso_cv_score_mae), np.mean(lasso_cv_score_mae_test),
                                           f'Log Lasso - {t}' )
        
        scores_lasso = pd.concat([scores_lasso, scores_lasso_temp], axis = 1)

scores_lasso.T
# Out:
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    5.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.2s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
#                                                     MAE Test   MAE Train  \
# Log Lasso - Age Adjusted Rate Endocrine           -10.981724  -11.254541
# Log Lasso - Age Adjusted Rate Obesity              -0.991579   -0.846487
# Log Lasso - Age Adjusted Rate Metabolic            -2.749544   -2.715866
# Log Lasso - Age Adjusted Rate Diabetes             -8.620157   -8.655300
# Log Lasso - Age Adjusted Rate Circulatory         -43.732278  -45.000088
# Log Lasso - Age Adjusted Rate Pulmonary            -2.463155   -2.033632
# Log Lasso - Age Adjusted Rate Arteries             -4.730114   -5.651906
# Log Lasso - Age Adjusted Rate Hypertension        -10.469795  -10.450502
# Log Lasso - Age Adjusted Rate External            -19.496031  -20.153525
# Log Lasso - Age Adjusted Rate Assault              -3.715980   -3.265110
# Log Lasso - Age Adjusted Rate Intentional          -4.293480   -4.407497
# Log Lasso - Age Adjusted Rate Transport            -7.248252   -7.510019
# Log Lasso - Age Adjusted Rate Mental              -11.435050  -12.249303
# Log Lasso - Age Adjusted Rate Psychoactive         -1.975130   -1.760507
# Log Lasso - Age Adjusted Rate Neoplasms           -25.653150  -25.755841
# Log Lasso - Age Adjusted Rate MalignantDigestive   -8.757333   -8.722180
# Log Lasso - Age Adjusted Rate MalignantBreast      -2.806403   -2.746765
# Log Lasso - Age Adjusted Rate MalignantFemale      -1.841095   -2.038583
# Log Lasso - Age Adjusted Rate MalignantMale        -3.186702   -2.609711
# Log Lasso - Age Adjusted Rate MalignantEndocrine   -0.116299   -0.147980
# Log Lasso - Age Adjusted Rate All                -108.833491 -103.069223
#
#                                                   R^2 Test  R^2 Train
# Log Lasso - Age Adjusted Rate Endocrine           0.254058   0.191407
# Log Lasso - Age Adjusted Rate Obesity             0.207106   0.211911
# Log Lasso - Age Adjusted Rate Metabolic           0.178060   0.104360
# Log Lasso - Age Adjusted Rate Diabetes            0.193075   0.277622
# Log Lasso - Age Adjusted Rate Circulatory         0.167859   0.196876
# Log Lasso - Age Adjusted Rate Pulmonary           0.046698   0.044266
# Log Lasso - Age Adjusted Rate Arteries            0.077286   0.045861
# Log Lasso - Age Adjusted Rate Hypertension        0.195334   0.210033
# Log Lasso - Age Adjusted Rate External            0.170264   0.171222
# Log Lasso - Age Adjusted Rate Assault            -0.249337   0.183769
# Log Lasso - Age Adjusted Rate Intentional         0.250394   0.230762
# Log Lasso - Age Adjusted Rate Transport           0.285106   0.265284
# Log Lasso - Age Adjusted Rate Mental              0.000318   0.031516
# Log Lasso - Age Adjusted Rate Psychoactive        0.213221   0.414949
# Log Lasso - Age Adjusted Rate Neoplasms           0.133670   0.120655
# Log Lasso - Age Adjusted Rate MalignantDigestive  0.092226   0.088646
# Log Lasso - Age Adjusted Rate MalignantBreast     0.101115   0.057121
# Log Lasso - Age Adjusted Rate MalignantFemale     0.069667   0.075982
# Log Lasso - Age Adjusted Rate MalignantMale       0.184301   0.182636
# Log Lasso - Age Adjusted Rate MalignantEndocrine  0.355101   0.439209
# Log Lasso - Age Adjusted Rate All                 0.189623   0.229311

# %% [markdown]
# ## <font color = darkorchid> Elastic Net Regression </font>

# %%
scores_enet = pd.DataFrame()

for t in target_list:
    # Drop if target value is not available
    df_enet = df.dropna(subset = [t])
    
    # Bootstrap observations
    df_enet_sample = df_enet.sample(n = df_enet.shape[0], replace = True)

    df_enet = pd.concat([df_enet, df_enet_sample])

    # Set features to percentage metrics
    X = df_enet[features_proportional_share_Log10]
    y = df_enet[t]
    
    # Train / Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    # StandardScale features
    #ss = StandardScaler()
    #X_train = ss.fit_transform(X_train)
    #X_test = ss.transform(X_test)
    
    ### Elastic Net CV

    # Instantiate and fit elastic net 
    l1_ratios = np.linspace(0.01, 1.0, 200)

    enet = linear_model.ElasticNetCV(l1_ratio=l1_ratios, n_alphas=200, cv=3, tol = 0.001, 
                                 max_iter = 2000, eps = 0.001)
    enet.fit(X_train, y_train)
    
    # Evaluate baseline train scores (MAE)
    enet_cv_score_mae = cross_val_score(enet, X_train, y_train , cv=3, 
                                        scoring = 'neg_mean_absolute_error', verbose = 1)
    
    # Evaluate baseline test scores (MAE)
    enet_cv_score_mae_test = cross_val_score(enet, X_test, y_test , cv=3, 
                                             scoring = 'neg_mean_absolute_error', verbose = 1)
    
    # Create dataframe of scores
    
    if scores_enet.shape[0] == 0:
        scores_enet = make_scores_df(enet.score(X_train, y_train), enet.score(X_test, y_test), 
                                     np.mean(enet_cv_score_mae), np.mean(enet_cv_score_mae_test),
                                     f'Log Elastic Net - {t}' )
    else:
        scores_enet_temp = make_scores_df(enet.score(X_train, y_train), enet.score(X_test, y_test), 
                                          np.mean(enet_cv_score_mae), np.mean(enet_cv_score_mae_test),
                                          f'Log Elastic Net - {t}' )
        
        scores_enet = pd.concat([scores_enet, scores_enet_temp], axis = 1)

scores_enet.T
# Out:
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   18.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  3.0min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.4min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   37.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.2min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   58.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.7min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   27.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.8min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   32.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   25.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.6min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   50.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.3min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   57.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   46.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   55.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   15.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   18.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  3.2min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   49.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.4min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.9min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.3min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.2min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   33.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  3.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.0min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   33.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   24.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   20.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   15.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   55.1s finished
#                                                       MAE Test   MAE Train  \
# Log Elastic Net - Age Adjusted Rate Endocrine       -11.178530  -11.367771
# Log Elastic Net - Age Adjusted Rate Obesity          -0.651968   -0.855010
# Log Elastic Net - Age Adjusted Rate Metabolic        -2.734745   -2.522050
# Log Elastic Net - Age Adjusted Rate Diabetes         -9.187708   -9.239442
# Log Elastic Net - Age Adjusted Rate Circulatory     -45.835493  -46.046816
# Log Elastic Net - Age Adjusted Rate Pulmonary        -2.413313   -2.524669
# Log Elastic Net - Age Adjusted Rate Arteries         -5.979737   -5.318093
# Log Elastic Net - Age Adjusted Rate Hypertension    -10.694734  -10.015960
# Log Elastic Net - Age Adjusted Rate External        -19.887796  -19.640866
# Log Elastic Net - Age Adjusted Rate Assault          -3.665302   -3.333411
# Log Elastic Net - Age Adjusted Rate Intentional      -4.642371   -4.458168
# Log Elastic Net - Age Adjusted Rate Transport        -8.168030   -7.760212
# Log Elastic Net - Age Adjusted Rate Mental          -12.017118  -11.992671
# Log Elastic Net - Age Adjusted Rate Psychoactive     -1.809912   -1.737648
# Log Elastic Net - Age Adjusted Rate Neoplasms       -25.812373  -25.586674
# Log Elastic Net - Age Adjusted Rate MalignantDi...   -8.719077   -8.543824
# Log Elastic Net - Age Adjusted Rate MalignantBr...   -2.639680   -2.788404
# Log Elastic Net - Age Adjusted Rate MalignantFe...   -1.907025   -1.874120
# Log Elastic Net - Age Adjusted Rate MalignantMale    -2.204230   -2.517496
# Log Elastic Net - Age Adjusted Rate MalignantEn...   -0.135114   -0.137014
# Log Elastic Net - Age Adjusted Rate All            -105.824028 -105.488985
#
#                                                     R^2 Test  R^2 Train
# Log Elastic Net - Age Adjusted Rate Endocrine       0.203549   0.187275
# Log Elastic Net - Age Adjusted Rate Obesity        -0.179484   0.147833
# Log Elastic Net - Age Adjusted Rate Metabolic       0.059851   0.119228
# Log Elastic Net - Age Adjusted Rate Diabetes        0.316778   0.217104
# Log Elastic Net - Age Adjusted Rate Circulatory     0.176305   0.177996
# Log Elastic Net - Age Adjusted Rate Pulmonary       0.130116   0.193213
# Log Elastic Net - Age Adjusted Rate Arteries        0.082957   0.161488
# Log Elastic Net - Age Adjusted Rate Hypertension    0.257277   0.196581
# Log Elastic Net - Age Adjusted Rate External        0.200684   0.184521
# Log Elastic Net - Age Adjusted Rate Assault         0.039422   0.147304
# Log Elastic Net - Age Adjusted Rate Intentional     0.191113   0.231916
# Log Elastic Net - Age Adjusted Rate Transport       0.170170   0.272242
# Log Elastic Net - Age Adjusted Rate Mental          0.024202   0.027052
# Log Elastic Net - Age Adjusted Rate Psychoactive    0.476794   0.509185
# Log Elastic Net - Age Adjusted Rate Neoplasms       0.111223   0.111864
# Log Elastic Net - Age Adjusted Rate MalignantDi...  0.097731   0.102659
# Log Elastic Net - Age Adjusted Rate MalignantBr...  0.026497   0.070094
# Log Elastic Net - Age Adjusted Rate MalignantFe...  0.030675   0.072870
# Log Elastic Net - Age Adjusted Rate MalignantMale   0.182344   0.132174
# Log Elastic Net - Age Adjusted Rate MalignantEn...  0.248080   0.519065
# Log Elastic Net - Age Adjusted Rate All             0.193239   0.221319

# %% [markdown]
# ## <font color = darkorchid> Bayesian Ridge </font>

# %%
scores_bayridge = pd.DataFrame()

for t in target_list:

    # Drop if target value is not available
    df_bayridge = df.dropna(subset = [t])

    # Bootstrap observations
    df_bayridge_sample = df_bayridge.sample(n = df_bayridge.shape[0], replace = True)

    df_bayridge = pd.concat([df_bayridge, df_bayridge_sample])

    # Set features to percentage metrics
    X = df_bayridge[features_proportional_share_Log10]
    y = df_bayridge[t]

    # Train / Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    # StandardScale features
    #ss = StandardScaler()
    #X_train = ss.fit_transform(X_train)
    #X_test = ss.transform(X_test)
    
    # Instantiate Bayesian Ridge Regression
    bayridge = linear_model.BayesianRidge(n_iter = 2000, tol = 0.001, 
                                          alpha_1 = 1e-06, alpha_2 = 1e-06, 
                                          lambda_1 = 1e-06, lambda_2 = 1e-06)

    bayridge.fit(X_train, y_train)
    

    # Evaluate baseline train scores (r2)
    bayridge_cv_score = cross_val_score(bayridge, X_train, y_train , cv=3, 
                                            scoring = 'r2', verbose = 1)

    # Evaluate baseline test scores (r2)
    bayridge_cv_score_test = cross_val_score(bayridge, X_test, y_test , cv=3, 
                                            scoring = 'r2', verbose = 1)

    # Evaluate baseline train scores (MAE)
    bayridge_cv_score_mae = cross_val_score(bayridge, X_train, y_train , cv=3, 
                                            scoring = 'neg_mean_absolute_error', verbose = 1, n_jobs = -1)

    # Evaluate baseline test scores (MAE)
    bayridge_cv_score_mae_test = cross_val_score(bayridge, X_test, y_test , cv=3, 
                                                 scoring = 'neg_mean_absolute_error', n_jobs = -1)

    # Create dataframe of scores
    
    if scores_bayridge.shape[0] == 0:
        scores_bayridge = make_scores_df(bayridge_cv_score, bayridge_cv_score_test, 
                                         bayridge_cv_score_mae, bayridge_cv_score_mae_test,
                                         f'Log Bayesian Ridge - {t}' )
    else:
        scores_bayridge_temp = make_scores_df(bayridge_cv_score, bayridge_cv_score_test, 
                                              bayridge_cv_score_mae, bayridge_cv_score_mae_test,
                                              f'Log Bayesian Ridge - {t}' )
        
        scores_bayridge = pd.concat([scores_bayridge, scores_bayridge_temp], axis = 1)
        
scores_bayridge.T
# Out:
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.0s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.2s finished
#                                                       MAE Test   MAE Train  \
# Log Bayesian Ridge - Age Adjusted Rate Endocrine    -11.363437  -11.033187
# Log Bayesian Ridge - Age Adjusted Rate Obesity       -0.785815   -1.008403
# Log Bayesian Ridge - Age Adjusted Rate Metabolic     -2.481707   -2.620719
# Log Bayesian Ridge - Age Adjusted Rate Diabetes      -9.247172   -8.816055
# Log Bayesian Ridge - Age Adjusted Rate Circulatory  -43.044395  -45.113870
# Log Bayesian Ridge - Age Adjusted Rate Pulmonary     -2.219322   -2.632240
# Log Bayesian Ridge - Age Adjusted Rate Arteries      -4.414087   -4.760098
# Log Bayesian Ridge - Age Adjusted Rate Hyperten...  -11.241181  -10.598566
# Log Bayesian Ridge - Age Adjusted Rate External     -19.712721  -19.198607
# Log Bayesian Ridge - Age Adjusted Rate Assault       -3.239536   -3.702910
# Log Bayesian Ridge - Age Adjusted Rate Intentional   -4.242784   -4.458095
# Log Bayesian Ridge - Age Adjusted Rate Transport     -6.926605   -7.658140
# Log Bayesian Ridge - Age Adjusted Rate Mental       -11.561530  -12.168711
# Log Bayesian Ridge - Age Adjusted Rate Psychoac...   -1.501807   -1.585542
# Log Bayesian Ridge - Age Adjusted Rate Neoplasms    -26.390757  -25.567842
# Log Bayesian Ridge - Age Adjusted Rate Malignan...   -8.899109   -8.621887
# Log Bayesian Ridge - Age Adjusted Rate Malignan...   -2.529886   -2.699650
# Log Bayesian Ridge - Age Adjusted Rate Malignan...   -1.898835   -1.929309
# Log Bayesian Ridge - Age Adjusted Rate Malignan...   -2.516856   -2.725763
# Log Bayesian Ridge - Age Adjusted Rate Malignan...   -0.142846   -0.102379
# Log Bayesian Ridge - Age Adjusted Rate All         -104.659589 -102.039786
#
#                                                     R^2 Test  R^2 Train
# Log Bayesian Ridge - Age Adjusted Rate Endocrine    0.249097   0.165419
# Log Bayesian Ridge - Age Adjusted Rate Obesity     -0.139697   0.133978
# Log Bayesian Ridge - Age Adjusted Rate Metabolic    0.032559   0.154669
# Log Bayesian Ridge - Age Adjusted Rate Diabetes     0.223827   0.214966
# Log Bayesian Ridge - Age Adjusted Rate Circulatory  0.209416   0.193351
# Log Bayesian Ridge - Age Adjusted Rate Pulmonary   -0.277198   0.084213
# Log Bayesian Ridge - Age Adjusted Rate Arteries     0.002450   0.012423
# Log Bayesian Ridge - Age Adjusted Rate Hyperten...  0.136121   0.213792
# Log Bayesian Ridge - Age Adjusted Rate External     0.133213   0.148983
# Log Bayesian Ridge - Age Adjusted Rate Assault     -0.087069   0.011549
# Log Bayesian Ridge - Age Adjusted Rate Intentional  0.136984   0.158717
# Log Bayesian Ridge - Age Adjusted Rate Transport    0.279068   0.205772
# Log Bayesian Ridge - Age Adjusted Rate Mental       0.005082   0.006851
# Log Bayesian Ridge - Age Adjusted Rate Psychoac...  0.522584   0.229924
# Log Bayesian Ridge - Age Adjusted Rate Neoplasms    0.083461   0.078394
# Log Bayesian Ridge - Age Adjusted Rate Malignan...  0.055854   0.076504
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -0.015235   0.041926
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -0.027559   0.011540
# Log Bayesian Ridge - Age Adjusted Rate Malignan...  0.095430   0.101159
# Log Bayesian Ridge - Age Adjusted Rate Malignan...  0.448139   0.310015
# Log Bayesian Ridge - Age Adjusted Rate All          0.200918   0.214676

# %% [markdown]
# ## <font color = darkorchid> Score Evaluation Ridge </font>

# %%
# Display scores for all diseases / all models
scores_combined = pd.merge(scores_lin_reg, scores_ridge, left_index = True, right_index = True)
scores_combined = pd.merge(scores_combined, scores_lasso, left_index = True, right_index = True)
scores_combined = pd.merge(scores_combined, scores_enet, left_index = True, right_index = True)
scores_combined = pd.merge(scores_combined, scores_bayridge, left_index = True, right_index = True)
scores_combined = scores_combined.T

scores_combined
# Out:
#                                                         MAE Test   MAE Train  \
# Log Linear Regression - Age Adjusted Rate Endoc... -1.197030e+01  -11.225318
# Log Linear Regression - Age Adjusted Rate Obesity  -1.967871e+10   -0.861631
# Log Linear Regression - Age Adjusted Rate Metab... -2.453518e+00   -2.548962
# Log Linear Regression - Age Adjusted Rate Diabetes -9.222473e+00   -8.815820
# Log Linear Regression - Age Adjusted Rate Circu... -4.563179e+01  -45.629989
# Log Linear Regression - Age Adjusted Rate Pulmo... -3.350013e+00   -2.237147
# Log Linear Regression - Age Adjusted Rate Arteries -5.973244e+00   -5.475674
# Log Linear Regression - Age Adjusted Rate Hyper... -1.027322e+01   -9.740101
# Log Linear Regression - Age Adjusted Rate External -2.090251e+01  -20.215868
# Log Linear Regression - Age Adjusted Rate Assault  -4.193660e+00   -4.296603
# Log Linear Regression - Age Adjusted Rate Inten... -4.516795e+00   -4.384833
# Log Linear Regression - Age Adjusted Rate Trans... -6.886124e+00   -8.015524
# Log Linear Regression - Age Adjusted Rate Mental   -1.225108e+01  -12.399513
# Log Linear Regression - Age Adjusted Rate Psych... -2.065729e+00   -1.617003
# Log Linear Regression - Age Adjusted Rate Neopl... -2.566797e+01  -26.142307
# Log Linear Regression - Age Adjusted Rate Malig... -8.901008e+00   -8.712827
# Log Linear Regression - Age Adjusted Rate Malig... -2.729884e+00   -2.799346
# Log Linear Regression - Age Adjusted Rate Malig... -2.100215e+00   -1.954341
# Log Linear Regression - Age Adjusted Rate Malig... -2.650665e+00   -2.781400
# Log Linear Regression - Age Adjusted Rate Malig... -2.370104e+09   -0.234742
# Log Linear Regression - Age Adjusted Rate All      -1.043729e+02 -103.968395
# Log Ridge - Age Adjusted Rate Endocrine            -1.132380e+01  -11.335230
# Log Ridge - Age Adjusted Rate Obesity              -7.445922e-01   -0.787173
# Log Ridge - Age Adjusted Rate Metabolic            -2.796444e+00   -2.560464
# Log Ridge - Age Adjusted Rate Diabetes             -8.695870e+00   -9.006685
# Log Ridge - Age Adjusted Rate Circulatory          -4.765411e+01  -44.612916
# Log Ridge - Age Adjusted Rate Pulmonary            -2.591769e+00   -2.295320
# Log Ridge - Age Adjusted Rate Arteries             -5.546729e+00   -4.903017
# Log Ridge - Age Adjusted Rate Hypertension         -1.112174e+01  -10.022309
# Log Ridge - Age Adjusted Rate External             -2.027220e+01  -19.735345
# ...                                                          ...         ...
# Log Elastic Net - Age Adjusted Rate Mental         -1.201712e+01  -11.992671
# Log Elastic Net - Age Adjusted Rate Psychoactive   -1.809912e+00   -1.737648
# Log Elastic Net - Age Adjusted Rate Neoplasms      -2.581237e+01  -25.586674
# Log Elastic Net - Age Adjusted Rate MalignantDi... -8.719077e+00   -8.543824
# Log Elastic Net - Age Adjusted Rate MalignantBr... -2.639680e+00   -2.788404
# Log Elastic Net - Age Adjusted Rate MalignantFe... -1.907025e+00   -1.874120
# Log Elastic Net - Age Adjusted Rate MalignantMale  -2.204230e+00   -2.517496
# Log Elastic Net - Age Adjusted Rate MalignantEn... -1.351143e-01   -0.137014
# Log Elastic Net - Age Adjusted Rate All            -1.058240e+02 -105.488985
# Log Bayesian Ridge - Age Adjusted Rate Endocrine   -1.136344e+01  -11.033187
# Log Bayesian Ridge - Age Adjusted Rate Obesity     -7.858150e-01   -1.008403
# Log Bayesian Ridge - Age Adjusted Rate Metabolic   -2.481707e+00   -2.620719
# Log Bayesian Ridge - Age Adjusted Rate Diabetes    -9.247172e+00   -8.816055
# Log Bayesian Ridge - Age Adjusted Rate Circulatory -4.304440e+01  -45.113870
# Log Bayesian Ridge - Age Adjusted Rate Pulmonary   -2.219322e+00   -2.632240
# Log Bayesian Ridge - Age Adjusted Rate Arteries    -4.414087e+00   -4.760098
# Log Bayesian Ridge - Age Adjusted Rate Hyperten... -1.124118e+01  -10.598566
# Log Bayesian Ridge - Age Adjusted Rate External    -1.971272e+01  -19.198607
# Log Bayesian Ridge - Age Adjusted Rate Assault     -3.239536e+00   -3.702910
# Log Bayesian Ridge - Age Adjusted Rate Intentional -4.242784e+00   -4.458095
# Log Bayesian Ridge - Age Adjusted Rate Transport   -6.926605e+00   -7.658140
# Log Bayesian Ridge - Age Adjusted Rate Mental      -1.156153e+01  -12.168711
# Log Bayesian Ridge - Age Adjusted Rate Psychoac... -1.501807e+00   -1.585542
# Log Bayesian Ridge - Age Adjusted Rate Neoplasms   -2.639076e+01  -25.567842
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -8.899109e+00   -8.621887
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -2.529886e+00   -2.699650
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -1.898835e+00   -1.929309
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -2.516856e+00   -2.725763
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -1.428463e-01   -0.102379
# Log Bayesian Ridge - Age Adjusted Rate All         -1.046596e+02 -102.039786
#
#                                                         R^2 Test  R^2 Train
# Log Linear Regression - Age Adjusted Rate Endoc...  2.006464e-01   0.143241
# Log Linear Regression - Age Adjusted Rate Obesity  -2.525960e+22  -0.131764
# Log Linear Regression - Age Adjusted Rate Metab...  6.107496e-02   0.065478
# Log Linear Regression - Age Adjusted Rate Diabetes  9.193800e-02   0.213337
# Log Linear Regression - Age Adjusted Rate Circu...  1.139644e-01   0.169662
# Log Linear Regression - Age Adjusted Rate Pulmo... -8.621794e-02   0.031992
# Log Linear Regression - Age Adjusted Rate Arteries -1.906051e-01   0.040363
# Log Linear Regression - Age Adjusted Rate Hyper...  5.816369e-02   0.176077
# Log Linear Regression - Age Adjusted Rate External  1.608626e-01   0.151708
# Log Linear Regression - Age Adjusted Rate Assault  -2.057082e+00  -0.149568
# Log Linear Regression - Age Adjusted Rate Inten...  1.071892e-01   0.096847
# Log Linear Regression - Age Adjusted Rate Trans...  2.011525e-01   0.232434
# Log Linear Regression - Age Adjusted Rate Mental   -1.753197e-02   0.016981
# Log Linear Regression - Age Adjusted Rate Psych... -7.323448e-01   0.364308
# Log Linear Regression - Age Adjusted Rate Neopl...  4.279978e-02   0.086206
# Log Linear Regression - Age Adjusted Rate Malig...  2.741774e-02   0.057484
# Log Linear Regression - Age Adjusted Rate Malig... -1.364055e-01   0.031805
# Log Linear Regression - Age Adjusted Rate Malig... -9.911535e-02  -0.002412
# Log Linear Regression - Age Adjusted Rate Malig...  3.442402e-02   0.045760
# Log Linear Regression - Age Adjusted Rate Malig... -2.912057e+21  -2.121898
# Log Linear Regression - Age Adjusted Rate All       2.065776e-01   0.197063
# Log Ridge - Age Adjusted Rate Endocrine             2.109220e-01   0.196516
# Log Ridge - Age Adjusted Rate Obesity               2.128902e-01   0.187625
# Log Ridge - Age Adjusted Rate Metabolic             1.291262e-01   0.116712
# Log Ridge - Age Adjusted Rate Diabetes              3.007665e-01   0.271409
# Log Ridge - Age Adjusted Rate Circulatory           1.582793e-01   0.200038
# Log Ridge - Age Adjusted Rate Pulmonary             8.526631e-02   0.096800
# Log Ridge - Age Adjusted Rate Arteries              3.005665e-02   0.095420
# Log Ridge - Age Adjusted Rate Hypertension          2.016362e-01   0.191771
# Log Ridge - Age Adjusted Rate External              1.257556e-01   0.169313
# ...                                                          ...        ...
# Log Elastic Net - Age Adjusted Rate Mental          2.420200e-02   0.027052
# Log Elastic Net - Age Adjusted Rate Psychoactive    4.767939e-01   0.509185
# Log Elastic Net - Age Adjusted Rate Neoplasms       1.112232e-01   0.111864
# Log Elastic Net - Age Adjusted Rate MalignantDi...  9.773111e-02   0.102659
# Log Elastic Net - Age Adjusted Rate MalignantBr...  2.649731e-02   0.070094
# Log Elastic Net - Age Adjusted Rate MalignantFe...  3.067463e-02   0.072870
# Log Elastic Net - Age Adjusted Rate MalignantMale   1.823441e-01   0.132174
# Log Elastic Net - Age Adjusted Rate MalignantEn...  2.480797e-01   0.519065
# Log Elastic Net - Age Adjusted Rate All             1.932390e-01   0.221319
# Log Bayesian Ridge - Age Adjusted Rate Endocrine    2.490971e-01   0.165419
# Log Bayesian Ridge - Age Adjusted Rate Obesity     -1.396971e-01   0.133978
# Log Bayesian Ridge - Age Adjusted Rate Metabolic    3.255928e-02   0.154669
# Log Bayesian Ridge - Age Adjusted Rate Diabetes     2.238274e-01   0.214966
# Log Bayesian Ridge - Age Adjusted Rate Circulatory  2.094162e-01   0.193351
# Log Bayesian Ridge - Age Adjusted Rate Pulmonary   -2.771982e-01   0.084213
# Log Bayesian Ridge - Age Adjusted Rate Arteries     2.450057e-03   0.012423
# Log Bayesian Ridge - Age Adjusted Rate Hyperten...  1.361206e-01   0.213792
# Log Bayesian Ridge - Age Adjusted Rate External     1.332127e-01   0.148983
# Log Bayesian Ridge - Age Adjusted Rate Assault     -8.706902e-02   0.011549
# Log Bayesian Ridge - Age Adjusted Rate Intentional  1.369843e-01   0.158717
# Log Bayesian Ridge - Age Adjusted Rate Transport    2.790677e-01   0.205772
# Log Bayesian Ridge - Age Adjusted Rate Mental       5.081752e-03   0.006851
# Log Bayesian Ridge - Age Adjusted Rate Psychoac...  5.225838e-01   0.229924
# Log Bayesian Ridge - Age Adjusted Rate Neoplasms    8.346142e-02   0.078394
# Log Bayesian Ridge - Age Adjusted Rate Malignan...  5.585439e-02   0.076504
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -1.523505e-02   0.041926
# Log Bayesian Ridge - Age Adjusted Rate Malignan... -2.755908e-02   0.011540
# Log Bayesian Ridge - Age Adjusted Rate Malignan...  9.543031e-02   0.101159
# Log Bayesian Ridge - Age Adjusted Rate Malignan...  4.481388e-01   0.310015
# Log Bayesian Ridge - Age Adjusted Rate All          2.009178e-01   0.214676
#
# [105 rows x 4 columns]

# %%
scores_combined.to_csv('./foodaccess_mortality_GLM_Log10_scores.csv')
