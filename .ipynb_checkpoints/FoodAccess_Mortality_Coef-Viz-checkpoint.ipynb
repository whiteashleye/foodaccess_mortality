# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./df_foodaccess_allmortality_SVI.csv')

# %%
coef = pd.read_csv('./LAShare_coefs.csv')

# %%
# Create DF of coefs for major disase chapters
major_diseases = coef[(coef['Target'] == 'Age Adjusted Rate All') | (coef['Target'] == 'Age Adjusted Rate Endocrine') | 
     (coef['Target'] == 'Age Adjusted Rate Neoplasms') | (coef['Target'] == 'Age Adjusted Rate External') |
     (coef['Target'] == 'Age Adjusted Rate Circulatory') | (coef['Target'] == 'Age Adjusted Rate Mental')
    ]

# %%
# Read in random forest feature importances
rf_feature_importance = pd.read_csv('./rf_feature_importance.csv')

rf_feature_importance.index = rf_feature_importance['Unnamed: 0']

rf_feature_importance.drop(columns = ['Unnamed: 0'], inplace = True)

rf_feature_importance.index.rename('Index', inplace = True)

# %%
# Read in randsom forest scores
rf_score = pd.read_csv('./rf_scores.csv')

rf_score.index = rf_score['Unnamed: 0']

rf_score.drop(columns=['Unnamed: 0'], inplace = True)

rf_score.index.rename('Index', inplace = True)

rf_score = rf_score.transpose()

rf_score['Avg R^2'] = (rf_score['R^2 Test'] + rf_score['R^2 Train']) / 2

rf_score['Target'] = rf_score.index

types = rf_score['Target'].str.split(expand = True)

rf_score['Target'] = types[6]

# %%
# Read in ElasticNet scores

enet = pd.read_csv('./enet_Log10_scores.csv')

enet.index = enet['Unnamed: 0']

enet.index.rename('Index', inplace = True)

enet.drop(columns = ['Unnamed: 0'], inplace = True)

enet = enet.transpose()

enet['Avg R^2'] = (enet['R^2 Test'] + enet['R^2 Train']) / 2

enet['Target'] = enet.index

enet['Target'] = enet['Target'].str.split(expand = True)[6]

# %%
# Plot Beta Coefs for Poisson Regression
f, ax = plt.subplots(figsize=(20, 5))
sns.pointplot(x = 'Feature', y = 'coef', data = major_diseases, hue = 'Target')
plt.xticks(rotation = 45, fontsize = 15)
plt.xlabel('Feature', fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel('Beta Coef', fontsize = 15)
plt.legend(fontsize = 12)
sns.set_color_codes("dark")
plt.title('Beta Coefficients for Poisson Regression', fontsize = 25);

# %%
# Plot Beta Coef p-values for Poisson Regression
f, ax = plt.subplots(figsize=(20, 5))
sns.pointplot(x = 'Feature', y = ' P>|z|  ', data = major_diseases, hue = 'Target')
plt.xticks(rotation = 45, fontsize = 15)
plt.xlabel('Feature', fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel('Avg P-Value', fontsize = 15)
plt.legend(fontsize = 12)
sns.set_color_codes("dark")
plt.title('Beta Coefficient P-Values for Poisson Regression', fontsize = 25);

# %%
# Plot random forest feature importance
f, ax = plt.subplots(figsize=(20,5))
sns.set_color_codes("dark")
sns.pointplot(x = rf_feature_importance.index, label = 'Feature Importance - Endocrine', 
              y = 'Feature Importance - Age Adjusted Rate Endocrine', data = rf_feature_importance, color = 'THISTLE')
sns.pointplot(x = rf_feature_importance.index, label = 'Feature Importance - Circulatory', 
              y = 'Feature Importance - Age Adjusted Rate All', data = rf_feature_importance, color = 'PLUM')
sns.pointplot(x = rf_feature_importance.index, label = 'Feature Importance - External', 
              y = 'Feature Importance - Age Adjusted Rate External', data = rf_feature_importance, color = 'FUCHSIA')
sns.pointplot(x = rf_feature_importance.index, label = 'Feature Importance - Mental', 
              y = 'Feature Importance - Age Adjusted Rate Mental', data = rf_feature_importance, color = 'DARKSLATEBLUE')
sns.pointplot(x = rf_feature_importance.index, label = 'Feature Importance - Neoplasms', 
              y = 'Feature Importance - Age Adjusted Rate Neoplasms', data = rf_feature_importance, color = 'DARKVIOLET')
sns.pointplot(x = rf_feature_importance.index, label = 'Feature Importance - All', 
              y = 'Feature Importance - Age Adjusted Rate All', data = rf_feature_importance, color = 'SLATEBLUE')
plt.xticks(rotation = 45, fontsize = 15)
plt.xlabel('Feature', fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel('Feature Importance', fontsize = 15)
plt.title('Feature Importance for Age Adjusted Rate', fontsize = 25)
plt.legend(fontsize = 12)
plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
rf_score.head()
# Out:
# Index                                           MAE Test  MAE Train  R^2 Test  \
# Random Forest - Age Adjusted Rate Endocrine   -11.505333  -7.486275  0.514422
# Random Forest - Age Adjusted Rate Obesity      -0.941022  -0.685761  0.210734
# Random Forest - Age Adjusted Rate Metabolic    -2.909557  -1.871114  0.555259
# Random Forest - Age Adjusted Rate Diabetes     -8.955051  -5.431739  0.562399
# Random Forest - Age Adjusted Rate Circulatory -47.451204 -29.984957  0.545401
#
# Index                                          R^2 Train   Avg R^2  \
# Random Forest - Age Adjusted Rate Endocrine     0.915200  0.714811
# Random Forest - Age Adjusted Rate Obesity       0.688249  0.449492
# Random Forest - Age Adjusted Rate Metabolic     0.704866  0.630062
# Random Forest - Age Adjusted Rate Diabetes      0.936767  0.749583
# Random Forest - Age Adjusted Rate Circulatory   0.908335  0.726868
#
# Index                                               Target
# Random Forest - Age Adjusted Rate Endocrine      Endocrine
# Random Forest - Age Adjusted Rate Obesity          Obesity
# Random Forest - Age Adjusted Rate Metabolic      Metabolic
# Random Forest - Age Adjusted Rate Diabetes        Diabetes
# Random Forest - Age Adjusted Rate Circulatory  Circulatory

# %%
# Plot R^2 for Random Forest
f, ax = plt.subplots(figsize=(25, 10))
sns.barplot(x = 'Target', y = 'R^2 Test', data = rf_score.sort_values('R^2 Test', ascending=False), orient = 'v')
plt.xticks(rotation = 45, fontsize = 18)
plt.xlabel('Target', fontsize = 18)
plt.yticks(fontsize = 18)
plt.ylabel('R^2 Test', fontsize = 18)
plt.title('R^2 Test', fontsize = 25);

# %%
# Plot R^2 for ElasticNet
f, ax = plt.subplots(figsize=(25, 10))
sns.barplot(x = 'Target', y = 'R^2 Test', data = enet.sort_values('R^2 Test', ascending=False), orient = 'v')
plt.xticks(rotation = 45, fontsize = 18)
plt.xlabel('Target', fontsize = 18)
plt.yticks(fontsize = 18)
plt.ylabel('R^2 Test', fontsize = 18)
plt.title('R^2 Test for Elastic Net', fontsize = 25);

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
df.head().T
# Out:
#                                                0            1          2  \
# County Code                                 1001         1003       1005
# STATE_ABBR                                    AL           AL         AL
# AGE17                                      14613        41898       6015
# AGE65                                       6546        30568       3909
# E_CROWD                                      260         1387        188
# E_LIMENG                                     229         2362        451
# E_MOBILE                                    4616        14464       3602
# E_MUNIT                                      389        15052        131
# E_NOHSDIP                                   4970        15103       5312
# E_NOVEH                                     1067         2305       1064
# E_PCI                                    24441.2        26472    16336.3
# E_PL_CROWD                                 0.423     0.494839   0.511667
# E_PL_LIMENG                               0.4285     0.430839   0.538778
# E_PL_MOBILE                             0.626167     0.571613   0.737667
# E_PL_MUNIT                               0.28075     0.547355   0.415111
# E_PL_NOHSDIP                              0.4215     0.315548      0.693
# E_PL_NOVEH                               0.52825     0.306645   0.634222
# E_PL_PCI                                0.335175     0.288955   0.714333
# E_PL_POV                                0.321583      0.32229   0.707444
# E_PL_UNEMP                              0.345083     0.351645   0.494333
# E_POV                                       5623        21216       6203
# E_UNEMP                                     1572         5356       1020
# GROUPQ                                       455         2307       3193
# HU                                         22135       104061      11829
# PL_AGE17                                0.742333     0.423323   0.393111
# PL_AGE65                                0.334333     0.645806   0.568889
# PL_GROUPQ                               0.365917     0.433452      0.322
# PL_MINORITY                             0.418583     0.277968   0.708111
# PL_SNGPRNT                              0.520083     0.342129   0.686444
# R_PL_THEME1                             0.328008     0.284255   0.679722
# R_PL_THEME2                             0.564667     0.422129   0.600333
# R_PL_THEME3                             0.450333     0.381323   0.705111
# R_PL_THEME4                             0.489083     0.547129      0.615
# R_PL_THEMES                             0.408142     0.368652   0.719511
# SNGPRNT                                     2390         7163       1603
# TOTPOP                                     54571       182265      27457
# County_x                                 Autauga      Baldwin    Barbour
# State                                    Alabama      Alabama    Alabama
# Age Adjusted Rate All                      889.3        814.1      943.9
# CensusTract                                   12           31          9
# Crude Rate All                             793.5        986.5     1030.7
# Deaths All                                   433         1798        283
# GroupQuartersFlag                              0            0          0
# LA1and10                                    0.75     0.483871   0.555556
# LA1and20                                     0.5     0.419355   0.222222
# LALOWI05_10                              10632.8      23336.9    4750.99
# LALOWI1_10                               6835.64      15459.8    3251.36
# LALOWI1_20                               3939.65      14323.9    518.702
# LAPOP05_10                               30141.6      72307.8    9302.72
# LAPOP1_10                                18092.7      46400.4    6683.98
# LAPOP1_20                                11064.9      43486.8    1182.18
# LAhalfand10                             0.833333     0.516129   0.555556
# LILATracts_1And10                       0.166667    0.0967742   0.333333
# LILATracts_1And20                      0.0833333    0.0967742   0.111111
# LILATracts_Vehicle                      0.166667    0.0645161   0.222222
# LILATracts_halfAnd10                    0.166667    0.0967742   0.333333
# LowIncomeTracts                         0.166667     0.225806   0.777778
# MedianFamilyIncome                       61082.9      60664.9      43123
# NUMGQTRS                                     455         2307       3193
# OHU2010                                    20221        73180       9820
# PCTGQTRS                               0.0107114     0.013246   0.088595
# POP2010                                    54571       182265      27457
# Population                                 54571       182265      27457
# PovertyRate                             0.138583     0.143581   0.245333
# TractBlack                                  9643        17105      12875
# TractHUNV                                   1081         2242        802
# TractHispanic                               1310         7992       1387
# TractLOWI                                  18692        63277      12484
# TractSNAP                                   2682         6471       2097
# TractWhite                                 42855       156153      13180
# lablack10                                2469.14      393.187    2552.97
# lablack10share                         0.0579099    0.0033803  0.0917296
# lablack20                                      0            0          0
# lablack20share                                 0            0          0
# lahisp10                                 107.656      20.7326     453.38
# lahisp10share                         0.00236693  0.000203921  0.0127248
# lahisp20                                       0            0          0
# lahisp20share                                  0            0          0
# lahunv10                                 167.557      43.1972    160.011
# lahunv10share                          0.0104347  0.000786904  0.0165119
# lahunv20                                       0            0          0
# lahunv20share                                  0            0          0
# lalowi10                                    2896         1136    2732.66
# lalowi10share                          0.0667593     0.012743  0.0954042
# lalowi20                                       0            0          0
# lalowi20share                                  0            0          0
# lapop10                                  7027.79      2913.54     5501.8
# lapop10share                             0.16006    0.0412431   0.183927
# lapop20                                        0            0          0
# lapop20share                                   0            0          0
# lasnap10                                 487.884      102.156    374.668
# lasnap10share                          0.0294958   0.00290499   0.039982
# lasnap20                                       0            0          0
# lasnap20share                                  0            0          0
# lawhite10                                4393.01      2419.67    2487.93
# lawhite10share                         0.0983808    0.0365767  0.0788156
# lawhite20                                      0            0          0
# lawhite20share                                 0            0          0
# Deaths Endocrine                              12           62         10
# Crude Rate Endocrine                          22           34       36.4
# Age Adjusted Rate Endocrine                 26.4         28.1       33.9
# Deaths Thyroid                               NaN          NaN        NaN
# Crude Rate Thyroid                           NaN          NaN        NaN
# Age Adjusted Rate Thyroid                    NaN          NaN        NaN
# Deaths Diabetes                              NaN           47        NaN
# Crude Rate Diabetes                          NaN         25.8        NaN
# Age Adjusted Rate Diabetes                   NaN         21.1        NaN
# Deaths Obesity                               NaN          NaN        NaN
# Crude Rate Obesity                           NaN          NaN        NaN
# Age Adjusted Rate Obesity                    NaN          NaN        NaN
# Deaths Metabolic                             NaN          NaN        NaN
# Crude Rate Metabolic                         NaN          NaN        NaN
# Age Adjusted Rate Metabolic                  NaN          NaN        NaN
# Deaths Circulatory                           155          619        116
# Crude Rate Circulatory                       284        339.6      422.5
# Age Adjusted Rate Circulatory              324.3          279      387.3
# Deaths Hypertension                          NaN           58        NaN
# Crude Rate Hypertension                      NaN         31.8        NaN
# Age Adjusted Rate Hypertension               NaN           26        NaN
# Deaths Pulmonary                             NaN          NaN        NaN
# Crude Rate Pulmonary                         NaN          NaN        NaN
# Age Adjusted Rate Pulmonary                  NaN          NaN        NaN
# Deaths Arteries                              NaN           24        NaN
# Crude Rate Arteries                          NaN         13.2        NaN
# Age Adjusted Rate Arteries                   NaN         10.5        NaN
# Deaths External                               36          124         18
# Crude Rate External                           66           68       65.6
# Age Adjusted Rate External                  66.6         66.4       56.8
# Deaths Transport                              10           30        NaN
# Crude Rate Transport                        18.3         16.5        NaN
# Age Adjusted Rate Transport                 18.5         16.9        NaN
# Deaths Intentional                            12           31        NaN
# Crude Rate Intentional                        22           17        NaN
# Age Adjusted Rate Intentional               21.1         16.6        NaN
# Deaths Assault                               NaN          NaN        NaN
# Crude Rate Assault                           NaN          NaN        NaN
# Age Adjusted Rate Assault                    NaN          NaN        NaN
# Deaths Mental                                 24           93        NaN
# Crude Rate Mental                             44           51        NaN
# Age Adjusted Rate Mental                    57.4         43.5        NaN
# Deaths Psychoactive                          NaN          NaN        NaN
# Crude Rate Psychoactive                      NaN          NaN        NaN
# Age Adjusted Rate Psychoactive               NaN          NaN        NaN
# Deaths Neoplasms                              85          434         67
# Crude Rate Neoplasms                       155.8        238.1        244
# Age Adjusted Rate Neoplasms                163.5        185.3      219.4
# Deaths MalignantDigestive                     18           96         15
# Crude Rate MalignantDigestive                 33         52.7       54.6
# Age Adjusted Rate MalignantDigestive        36.4           40       50.4
# Deaths MalignantBreast                       NaN           24        NaN
# Crude Rate MalignantBreast                   NaN         13.2        NaN
# Age Adjusted Rate MalignantBreast            NaN         10.6        NaN
# Deaths MalignantFemale                       NaN           19        NaN
# Crude Rate MalignantFemale                   NaN         10.4        NaN
# Age Adjusted Rate MalignantFemale            NaN          7.9        NaN
# Deaths MalignantMale                         NaN           27        NaN
# Crude Rate MalignantMale                     NaN         14.8        NaN
# Age Adjusted Rate MalignantMale              NaN         12.3        NaN
# Deaths MalignantEndocrine                    NaN          NaN        NaN
# Crude Rate MalignantEndocrine                NaN          NaN        NaN
# Age Adjusted Rate MalignantEndocrine         NaN          NaN        NaN
#
#                                                 3            4
# County Code                                  1007         1009
# STATE_ABBR                                     AL           AL
# AGE17                                        5201        14106
# AGE65                                        2906         8439
# E_CROWD                                        90          567
# E_LIMENG                                      169         1607
# E_MOBILE                                     2666         5278
# E_MUNIT                                       148          128
# E_NOHSDIP                                    3839         9651
# E_NOVEH                                       406          707
# E_PCI                                     20201.5      21016.3
# E_PL_CROWD                                0.37125     0.689222
# E_PL_LIMENG                               0.63525     0.686667
# E_PL_MOBILE                               0.83475     0.697778
# E_PL_MUNIT                                  0.404     0.261667
# E_PL_NOHSDIP                              0.69725        0.692
# E_PL_NOVEH                                  0.466     0.330333
# E_PL_PCI                                 0.497225     0.456367
# E_PL_POV                                    0.338     0.380222
# E_PL_UNEMP                                0.52025     0.422889
# E_POV                                        2830         7510
# E_UNEMP                                       974         1975
# GROUPQ                                       2224          489
# HU                                           8981        23887
# PL_AGE17                                  0.51175     0.630556
# PL_AGE65                                  0.37625     0.524111
# PL_GROUPQ                                  0.5945     0.462778
# PL_MINORITY                                0.3475     0.195889
# PL_SNGPRNT                                  0.491     0.241444
# R_PL_THEME1                              0.511275     0.479911
# R_PL_THEME2                               0.39025        0.408
# R_PL_THEME3                               0.54775     0.506889
# R_PL_THEME4                               0.63025        0.572
# R_PL_THEMES                              0.561675     0.508667
# SNGPRNT                                       966         1866
# TOTPOP                                      22915        57322
# County_x                                     Bibb       Blount
# State                                     Alabama      Alabama
# Age Adjusted Rate All                       994.4        890.7
# CensusTract                                     4            9
# Crude Rate All                              981.9        945.5
# Deaths All                                    225          542
# GroupQuartersFlag                               0            0
# LA1and10                                        0     0.222222
# LA1and20                                        0     0.111111
# LALOWI05_10                               164.903      3231.16
# LALOWI1_10                                164.903       2570.9
# LALOWI1_20                                      0       1674.6
# LAPOP05_10                                295.614      7387.08
# LAPOP1_10                                 295.614      5855.94
# LAPOP1_20                                       0      3900.42
# LAhalfand10                                     0     0.222222
# LILATracts_1And10                               0            0
# LILATracts_1And20                               0            0
# LILATracts_Vehicle                           0.25     0.222222
# LILATracts_halfAnd10                            0            0
# LowIncomeTracts                                 1     0.444444
# MedianFamilyIncome                        43362.5        52136
# NUMGQTRS                                     2224          489
# OHU2010                                      7953        21578
# PCTGQTRS                                0.0656285   0.00805428
# POP2010                                     22915        57322
# Population                                  22915        57322
# PovertyRate                               0.16025     0.179111
# TractBlack                                   5047          761
# TractHUNV                                     299          823
# TractHispanic                                 406         4626
# TractLOWI                                   10123        22865
# TractSNAP                                    1125         2900
# TractWhite                                  17381        53068
# lablack10                                 10.9248      20.5444
# lablack10share                        0.000506624  0.000261758
# lablack20                                       0            0
# lablack20share                                  0            0
# lahisp10                                  2.94426       49.994
# lahisp10share                         0.000136536  0.000652017
# lahisp20                                        0            0
# lahisp20share                                   0            0
# lahunv10                                   0.8507      19.1151
# lahunv10share                         8.90842e-05  0.000645294
# lahunv20                                        0            0
# lahunv20share                                   0            0
# lalowi10                                  164.903      896.301
# lalowi10share                          0.00742223    0.0114636
# lalowi20                                        0            0
# lalowi20share                                   0            0
# lapop10                                   295.614      1955.52
# lapop10share                            0.0132063    0.0250581
# lapop20                                         0            0
# lapop20share                                    0            0
# lasnap10                                  16.2934      99.8834
# lasnap10share                          0.00188192   0.00340244
# lasnap20                                        0            0
# lasnap20share                                   0            0
# lawhite10                                 279.639      1875.94
# lawhite10share                           0.012474    0.0240353
# lawhite20                                       0            0
# lawhite20share                                  0            0
# Deaths Endocrine                              NaN           10
# Crude Rate Endocrine                          NaN         17.4
# Age Adjusted Rate Endocrine                   NaN         15.1
# Deaths Thyroid                                NaN          NaN
# Crude Rate Thyroid                            NaN          NaN
# Age Adjusted Rate Thyroid                     NaN          NaN
# Deaths Diabetes                               NaN          NaN
# Crude Rate Diabetes                           NaN          NaN
# Age Adjusted Rate Diabetes                    NaN          NaN
# Deaths Obesity                                NaN          NaN
# Crude Rate Obesity                            NaN          NaN
# Age Adjusted Rate Obesity                     NaN          NaN
# Deaths Metabolic                              NaN          NaN
# Crude Rate Metabolic                          NaN          NaN
# Age Adjusted Rate Metabolic                   NaN          NaN
# Deaths Circulatory                             81          168
# Crude Rate Circulatory                      353.5        293.1
# Age Adjusted Rate Circulatory               368.9        283.1
# Deaths Hypertension                           NaN          NaN
# Crude Rate Hypertension                       NaN          NaN
# Age Adjusted Rate Hypertension                NaN          NaN
# Deaths Pulmonary                              NaN          NaN
# Crude Rate Pulmonary                          NaN          NaN
# Age Adjusted Rate Pulmonary                   NaN          NaN
# Deaths Arteries                               NaN          NaN
# Crude Rate Arteries                           NaN          NaN
# Age Adjusted Rate Arteries                    NaN          NaN
# Deaths External                                19           46
# Crude Rate External                          82.9         80.2
# Age Adjusted Rate External                   84.5         80.8
# Deaths Transport                               10           10
# Crude Rate Transport                         43.6         17.4
# Age Adjusted Rate Transport                  43.9         18.4
# Deaths Intentional                            NaN           11
# Crude Rate Intentional                        NaN         19.2
# Age Adjusted Rate Intentional                 NaN         19.7
# Deaths Assault                                NaN          NaN
# Crude Rate Assault                            NaN          NaN
# Age Adjusted Rate Assault                     NaN          NaN
# Deaths Mental                                 NaN           16
# Crude Rate Mental                             NaN         27.9
# Age Adjusted Rate Mental                      NaN         26.6
# Deaths Psychoactive                           NaN          NaN
# Crude Rate Psychoactive                       NaN          NaN
# Age Adjusted Rate Psychoactive                NaN          NaN
# Deaths Neoplasms                               57          126
# Crude Rate Neoplasms                        248.7        219.8
# Age Adjusted Rate Neoplasms                 243.1        189.6
# Deaths MalignantDigestive                      14           20
# Crude Rate MalignantDigestive                61.1         34.9
# Age Adjusted Rate MalignantDigestive         56.2         32.2
# Deaths MalignantBreast                        NaN          NaN
# Crude Rate MalignantBreast                    NaN          NaN
# Age Adjusted Rate MalignantBreast             NaN          NaN
# Deaths MalignantFemale                        NaN          NaN
# Crude Rate MalignantFemale                    NaN          NaN
# Age Adjusted Rate MalignantFemale             NaN          NaN
# Deaths MalignantMale                          NaN          NaN
# Crude Rate MalignantMale                      NaN          NaN
# Age Adjusted Rate MalignantMale               NaN          NaN
# Deaths MalignantEndocrine                     NaN          NaN
# Crude Rate MalignantEndocrine                 NaN          NaN
# Age Adjusted Rate MalignantEndocrine          NaN          NaN

# %%
df['LAPOP05_10'].sum()
# Out:
# 149270330.41029832

# %%
df['LAPOP1_10'].sum()
# Out:
# 67339493.99879259

# %%
df['LAPOP1_20'].sum()
# Out:
# 62842465.989905275
